# %% [markdown]
# # Data-Driven Optimisation - PCA
#
# In this notebook, we will run data driven algorithm to optimise the parameter of our problem

# %%
import Model #import the simulation and the model
import Algorithm #import data-driven algorithms 
import numpy as np
import matplotlib.pyplot as plt
# Out:
# pybullet build time: Mar  5 2024 15:57:27

# %% [markdown]
# ## PCA

# %%
principal_components,result,pca,labels,df = Algorithm.pca(25,4)
# Out:
# Create pool
# new model
# start simulation
# max high 0.12 [m] max distance 0.03 [m] energy  509.78 J
# new model
# start simulation
# max high 0.18 [m] max distance 0.35 [m] energy  3298.55 J
# new model
# start simulation
# max high 198.68 [m] max distance 197.17 [m] energy  97.38 J
# new model
# start simulation
# max high 0.14 [m] max distance 0.77 [m] energy  771.61 J
# new model
# start simulation
# max high 0.93 [m] max distance 9.42 [m] energy  2459.59 J
# new model
# start simulation
# max high 3.76 [m] max distance 1.6 [m] energy  1343.63 J
# new model
# start simulation
# max high 0.05 [m] max distance 0.01 [m] energy  189.78 J
# new model
# start simulation
# max high 0.15 [m] max distance 0.02 [m] energy  503.01 J
# new model
# start simulation
# max high 2.95 [m] max distance 21.75 [m] energy  1465.86 J
# new model
# start simulation
# max high 3.28 [m] max distance 4.18 [m] energy  2191.77 J
# new model
# start simulation
# max high 0.15 [m] max distance 0.03 [m] energy  849.1 J
# new model
# start simulation
# max high 0.36 [m] max distance 0.26 [m] energy  134.48 J
# new model
# start simulation
# max high 0.12 [m] max distance 0.01 [m] energy  1404.36 J
# new model
# start simulation
# max high 0.11 [m] max distance 0.03 [m] energy  267.76 J
# new model
# start simulation
# max high 1.58 [m] max distance 0.99 [m] energy  151.41 J
# new model
# start simulation
# max high 1.82 [m] max distance 1.21 [m] energy  90.64 J
# new model
# start simulation
# max high 0.15 [m] max distance 0.02 [m] energy  66.39 J
# new model
# start simulation
# max high 49.35 [m] max distance 1.22 [m] energy  434.17 J
# new model
# start simulation
# max high 1.08 [m] max distance 3.28 [m] energy  1438.29 J
# new model
# start simulation
# max high 0.17 [m] max distance 0.14 [m] energy  317.08 J
# new model
# start simulation
# max high 0.06 [m] max distance 0.23 [m] energy  3664.32 J
# new model
# start simulation
# max high 2.67 [m] max distance 4.58 [m] energy  2560.99 J
# new model
# start simulation
# max high 0.14 [m] max distance 0.12 [m] energy  1364.72 J
# new model
# start simulation
# max high 0.13 [m] max distance 1.48 [m] energy  3134.06 J
# new model
# start simulation
# max high 0.13 [m] max distance 0.03 [m] energy  1727.45 J
#          Link1       Link2       Link3       Link4       Link5 Compression  \
# 0    95.646296  102.928805  131.086145   81.579938  124.647449    9.212194
# 1   149.150209   93.037459    21.82929  101.576108   78.285569   26.953317
# 2    24.648816   38.600736   70.279413    125.9824  110.694026    6.948295
# 3   118.000501   43.757885  144.896127    63.42442   55.126413   26.608195
