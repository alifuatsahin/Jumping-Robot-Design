# %% [markdown]
# # Data-Driven Optimisation - PCA
#
# In this notebook, we will run data driven algorithm to optimise the parameter of our problem

# %%
import Model #import the simulation and the model
import Algorithm #import data-driven algorithms 
import numpy as np
import matplotlib.pyplot as plt
# Out:
# pybullet build time: Mar  5 2024 15:57:27

# %% [markdown]
# ## PCA

# %%
principal_components,result,pca,labels,df = Algorithm.pca(25,4)
# Out:
# Create pool
# new model
# start simulation
# max high 0.04 [m] max distance 0.08 [m] energy  0.02 J
# new model
# start simulation
# max high 0 [m] max distance 0 [m] energy  0.0 J
# new model
# start simulation
# max high 0 [m] max distance 0 [m] energy  0.02 J
# new model
# start simulation
# max high 0 [m] max distance 0 [m] energy  0.2 J
# new model
# start simulation
# max high 0 [m] max distance 0 [m] energy  0.0 J
# new model
# start simulation
# max high 0 [m] max distance 0 [m] energy  0.0 J
# new model
# start simulation
# max high 0 [m] max distance 0 [m] energy  0.0 J
# new model
# start simulation
# max high 0 [m] max distance 0 [m] energy  0.0 J
# new model
# start simulation
# max high 0 [m] max distance 0 [m] energy  0.0 J
# new model
# start simulation
# max high 0 [m] max distance 0 [m] energy  0.0 J
# new model
# start simulation
# max high 0 [m] max distance 0 [m] energy  0.63 J
# new model
# start simulation
# max high 0 [m] max distance 0 [m] energy  0.0 J
# new model
# start simulation
# max high 0 [m] max distance 0 [m] energy  0.55 J
# new model
# start simulation
# max high 0 [m] max distance 0 [m] energy  0.01 J
# new model
# start simulation
# max high 0 [m] max distance 0 [m] energy  0.0 J
# new model
# start simulation
# max high 0 [m] max distance 0 [m] energy  0.37 J
# new model
# start simulation
# max high 0 [m] max distance 0 [m] energy  0.12 J
# new model
# start simulation
# max high 0 [m] max distance 0 [m] energy  2.2 J
# new model
# start simulation
# max high 0 [m] max distance 0 [m] energy  0.0 J
# new model
# start simulation
# max high 0 [m] max distance 0 [m] energy  0.0 J
# new model
# start simulation
# max high 0 [m] max distance 0 [m] energy  0.0 J
# new model
# start simulation
# max high 0 [m] max distance 0 [m] energy  0.0 J
# new model
# start simulation
# max high 0 [m] max distance 0 [m] energy  0.01 J
# new model
# start simulation
# max high 0 [m] max distance 0 [m] energy  0.0 J
# new model
# start simulation
# max high 0 [m] max distance 0 [m] energy  0.0 J
#          Link1       Link2       Link3       Link4       Link5 Compression  \
# 0    21.875491   31.733464   28.960116   83.200788  126.449488    22.74374
# 1    96.236433    86.03655   141.00729   37.500888  146.700425   17.464497
# 2    113.68771   95.974474  119.676128   57.827721   32.803616   27.635497
# 3    22.601117  123.257974  110.745104   20.401262   90.947978   17.820341
# 4    48.453077   97.201284  148.399881   28.788418   96.637585   22.908191
# 5    72.072702  126.316134   119.53959  117.535738  121.760852   21.761329
# 6   123.531128   81.561994   91.786885  143.056634   33.221691   23.291598
# 7    78.775026   55.055821  125.641779   77.519442   97.969284   25.959138
# 8    21.452992  135.218184  131.065013   138.12079  108.677584   26.793484
# 9   106.762191   66.906842    66.31711  118.996305  123.664086    9.815716
# 10   31.592976   30.439546  149.921481    48.57295  102.180145   20.789597
# 11   92.217714   81.100468   58.643148  125.293406   38.267443   10.969713
# 12  120.322807  132.255795   49.285572  124.538805   31.017612    7.134498
# 13   20.737086   37.312526   94.484899  129.546297   48.694675   20.419798
# 14  120.173616   50.280499  131.297818    112.6876     48.9438    24.41302
# 15   85.328712  131.904134   53.386089   98.948752   56.717038    6.093877
# 16   92.692425   41.933517   63.972459     31.4805  141.332335    7.793959
# 17   43.632441  124.975015   26.678554   24.454099    66.85081   21.461315
# 18  110.570182   44.611457  147.545365  138.549347   44.629152   29.273828
# 19   95.900427  117.294829   97.267983  121.697947   78.378385   25.860353
# 20   48.151022   42.149792   23.878031    47.08114   45.966418   18.374221
# 21   87.089798  111.205326     87.2037  118.741249  122.242771    14.15993
# 22   90.256936   67.993934   94.513942    50.19078  114.640934   12.622182
# 23   43.511467  103.858435   34.044239  115.271162   68.375669    17.01454
# 24  137.881537   46.064905  113.120038   40.225447   143.37269   25.771313
#
#          Rest     Spring
# 0   76.144174   9.245427
# 1   24.361474  10.481449
# 2   50.721877  13.001274
# 3   25.055245    5.77279
# 4   17.978627  11.767739
# 5   26.984199   7.169752
# 6   34.066537   9.870583
# 7    42.54427  10.709942
# 8   24.131354   6.770542
# 9   14.343643   9.614917
# 10  67.814824   9.857115
# 11  11.535688    6.34267
# 12   11.34977   9.395161
# 13  23.739463   8.218553
# 14  22.265917  10.382526
# 15  28.646448   9.888207
# 16  60.375812   8.850559
# 17  55.690773  12.560741
# 18  56.787568   7.976476
# 19  71.244502  11.699038
# 20   73.23867   4.975188
# 21  52.384959  11.351666
# 22  39.246177   6.912239
# 23  75.070553  13.825172
# 24  78.898953   6.859096
#            0
# 0   3.393076
# 1   0.000000
# 2   0.000000
# 3   0.000000
# 4   0.000000
# 5   0.000000
# 6   0.000000
# 7   0.000000
# 8   0.000000
# 9   0.000000
# 10  0.000000
# 11  0.000000
# 12  0.000000
# 13  0.000000
# 14  0.000000
# 15  0.000000
# 16  0.000000
# 17  0.000000
# 18  0.000000
# 19  0.000000
# 20  0.000000
# 21  0.000000
# 22  0.000000
# 23  0.000000
# 24  0.000000
# apply PCA

# %%
Algorithm.biplot(principal_components,result, pca, labels=labels, label_size=8, arrow_length=5, arrow_width=0.01)

# %%
Algorithm.pca_plot(principal_components,result)
