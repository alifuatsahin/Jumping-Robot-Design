# %% [markdown]
# # Data-Driven Optimisation - PCA
#
# In this notebook, we will run data driven algorithm to optimise the parameter of our problem

# %%
import Model #import the simulation and the model
import Algorithm #import data-driven algorithms 
import numpy as np
import matplotlib.pyplot as plt
# Out:
# pybullet build time: Mar  5 2024 15:57:27

# %% [markdown]
# ## PCA

# %%
principal_components,result,pca,labels,df = Algorithm.pca(300,4)
# Out:
# Create pool
# new model
# start simulation
# max high 0.157 [m] max distance 0.007 [m] energy  0.0212 J
# new model
# start simulation
# max high 0.121 [m] max distance 0.0 [m] energy  0.0021 J
# new model
# start simulation
# max high 0.09 [m] max distance 0.002 [m] energy  0.0045 J
# new model
# start simulation
# max high 0.163 [m] max distance 0.011 [m] energy  0.0019 J
# new model
# start simulation
# max high 0.165 [m] max distance 0.003 [m] energy  0.0015 J
# new model
# start simulation
# max high 0.16 [m] max distance 0.003 [m] energy  0.0002 J
# new model
# start simulation
# max high 0.156 [m] max distance 0.002 [m] energy  0.0421 J
# new model
# start simulation
# max high 0.109 [m] max distance 0.215 [m] energy  0.0 J
# new model
# start simulation
# max high 0.148 [m] max distance 0.001 [m] energy  0.0017 J
# new model
# start simulation
# max high 0.15 [m] max distance 0.0 [m] energy  0.0 J
# new model
# start simulation
# max high 0.089 [m] max distance 0.021 [m] energy  0.0013 J
# new model
# start simulation
# max high 0.079 [m] max distance 0.022 [m] energy  0.0001 J
# new model
# start simulation
# max high 0.157 [m] max distance 0.003 [m] energy  0.0181 J
# new model
# start simulation
# max high 0.123 [m] max distance 0.043 [m] energy  0.001 J
# new model
# start simulation
# max high 0.148 [m] max distance 0.005 [m] energy  0.0067 J
# new model
# start simulation
# max high 0.096 [m] max distance 0.001 [m] energy  0.0001 J
# new model
# start simulation
# max high 0.127 [m] max distance 0.161 [m] energy  0.0 J
# new model
# start simulation
# max high 0.158 [m] max distance 0.002 [m] energy  0.0079 J
# new model
# start simulation
# max high 0.086 [m] max distance 0.005 [m] energy  0.0024 J
# new model
# start simulation
# max high 0.076 [m] max distance 0.004 [m] energy  0.004 J
# new model
# start simulation
# max high 0.161 [m] max distance 0.002 [m] energy  0.0187 J
# new model
# start simulation
# max high 0.162 [m] max distance 0.001 [m] energy  0.0044 J
# new model
# start simulation
# max high 0.12 [m] max distance 0.0 [m] energy  0.0034 J
# new model
# start simulation
# max high 0.139 [m] max distance 0.004 [m] energy  0.0217 J
# new model
# start simulation
# max high 0.165 [m] max distance 0.012 [m] energy  0.0069 J
# new model
# start simulation
# max high 0.156 [m] max distance 0.01 [m] energy  0.0017 J
# new model
# start simulation
# max high 0.097 [m] max distance 0.005 [m] energy  0.0 J
# new model
# start simulation
# max high 0.102 [m] max distance 0.023 [m] energy  0.0018 J
# new model
# start simulation
# max high 0.108 [m] max distance 0.001 [m] energy  0.0169 J
# new model
# start simulation
# max high 0.097 [m] max distance 0.005 [m] energy  0.0107 J
# new model
# start simulation
# max high 0.162 [m] max distance 0.008 [m] energy  0.0029 J
# new model
# start simulation
# max high 0.118 [m] max distance 0.002 [m] energy  0.0014 J
# new model
# start simulation
# max high 0.141 [m] max distance 0.011 [m] energy  0.0039 J
# new model
# start simulation
# max high 0.116 [m] max distance 0.002 [m] energy  0.0077 J
# new model
# start simulation
# max high 0.131 [m] max distance 0.006 [m] energy  0.0016 J
# new model
# start simulation
# max high 0.117 [m] max distance 0.013 [m] energy  0.0 J
# new model
# start simulation
# max high 0.135 [m] max distance 0.019 [m] energy  0.0 J
# new model
# start simulation
# max high 0.121 [m] max distance 0.001 [m] energy  0.0059 J
# new model
# start simulation
# max high 0.125 [m] max distance 0.001 [m] energy  0.0091 J
# new model
# start simulation
# max high 0.078 [m] max distance 0.0 [m] energy  0.0005 J
# new model
# start simulation
# max high 0.14 [m] max distance 0.025 [m] energy  0.0046 J
# new model
# start simulation
# max high 0.136 [m] max distance 0.003 [m] energy  0.0159 J
# new model
# start simulation
# max high 0.083 [m] max distance 0.003 [m] energy  0.002 J
# new model
# start simulation
# max high 0.155 [m] max distance 0.001 [m] energy  0.0143 J
# new model
# start simulation
# max high 0.154 [m] max distance 0.011 [m] energy  0.0142 J
# new model
# start simulation
# max high 0.144 [m] max distance 0.003 [m] energy  0.0263 J
# new model
# start simulation
# max high 0.117 [m] max distance 0.004 [m] energy  0.0014 J
# new model
# start simulation
# max high 0.171 [m] max distance 0.031 [m] energy  0.0024 J
# new model
# start simulation
# max high 0.103 [m] max distance 0.021 [m] energy  0.0008 J
# new model
# start simulation
# max high 0.128 [m] max distance 0.009 [m] energy  0.001 J
# new model
# start simulation
# max high 0.088 [m] max distance 0.01 [m] energy  0.0006 J
# new model
# start simulation
# max high 0.087 [m] max distance 0.222 [m] energy  0.0 J
# new model
# start simulation
# max high 0.142 [m] max distance 0.001 [m] energy  0.0154 J
# new model
# start simulation
# max high 0.132 [m] max distance 0.001 [m] energy  0.0049 J
# new model
# start simulation
# max high 0.16 [m] max distance 0.002 [m] energy  0.0047 J
# new model
# start simulation
# max high 0.179 [m] max distance 0.013 [m] energy  0.0 J
# new model
# start simulation
# max high 0.087 [m] max distance 0.001 [m] energy  0.0004 J
# new model
# start simulation
# max high 0.142 [m] max distance 0.0 [m] energy  0.0114 J
# new model
# start simulation
# max high 0.114 [m] max distance 0.013 [m] energy  0.0006 J
# new model
# start simulation
# max high 0.13 [m] max distance 0.109 [m] energy  0.0027 J
# new model
# start simulation
# max high 0.112 [m] max distance 0.009 [m] energy  0.0026 J
# new model
# start simulation
# max high 0.133 [m] max distance 0.0 [m] energy  0.0098 J
# new model
# start simulation
# max high 0.126 [m] max distance 0.002 [m] energy  0.029 J
# new model
# start simulation
# max high 0.136 [m] max distance 0.011 [m] energy  0.0024 J
# new model
# start simulation
# max high 0.146 [m] max distance 0.001 [m] energy  0.0035 J
# new model
# start simulation
# max high 0.102 [m] max distance 0.002 [m] energy  0.0022 J
# new model
# start simulation
# max high 0.104 [m] max distance 0.017 [m] energy  0.0008 J
# new model
# start simulation
# max high 0.109 [m] max distance 0.0 [m] energy  0.0048 J
# new model
# start simulation
# max high 0.168 [m] max distance 0.064 [m] energy  0.032 J
# new model
# start simulation
# max high 0.164 [m] max distance 0.001 [m] energy  0.0214 J
# new model
# start simulation
# max high 0.137 [m] max distance 0.022 [m] energy  0.0021 J
# new model
# start simulation
# max high 0.171 [m] max distance 0.046 [m] energy  0.0072 J
# new model
# start simulation
# max high 0.171 [m] max distance 0.052 [m] energy  0.0143 J
# new model
# start simulation
# max high 0.094 [m] max distance 0.003 [m] energy  0.0128 J
# new model
# start simulation
# max high 0.143 [m] max distance 0.001 [m] energy  0.0124 J
# new model
# start simulation
# max high 0.117 [m] max distance 0.112 [m] energy  0.0021 J
# new model
# start simulation
# max high 0.169 [m] max distance 0.006 [m] energy  0.0676 J
# new model
# start simulation
# max high 0.138 [m] max distance 0.002 [m] energy  0.0216 J
# new model
# start simulation
# max high 0.143 [m] max distance 0.003 [m] energy  0.0044 J
# new model
# start simulation
# max high 0.095 [m] max distance 0.004 [m] energy  0.0007 J
# new model
# start simulation
# max high 0.136 [m] max distance 0.027 [m] energy  0.0001 J
# new model
# start simulation
# max high 0.104 [m] max distance 0.005 [m] energy  0.0016 J
# new model
# start simulation
# max high 0.106 [m] max distance 0.003 [m] energy  0.0175 J
# new model
# start simulation
# max high 0.169 [m] max distance 0.004 [m] energy  0.0171 J
# new model
# start simulation
# max high 0.139 [m] max distance 0.006 [m] energy  0.0482 J
# new model
# start simulation
# max high 0.108 [m] max distance 0.001 [m] energy  0.0092 J
# new model
# start simulation
# max high 0.143 [m] max distance 0.006 [m] energy  0.0175 J
# new model
# start simulation
# max high 0.146 [m] max distance 0.004 [m] energy  0.0077 J
# new model
# start simulation
# max high 0.103 [m] max distance 0.002 [m] energy  0.0015 J
# new model
# start simulation
# max high 0.134 [m] max distance 0.001 [m] energy  0.003 J
# new model
# start simulation
# max high 0.135 [m] max distance 0.067 [m] energy  0.0019 J
# new model
# start simulation
# max high 0.139 [m] max distance 0.002 [m] energy  0.0024 J
# new model
# start simulation
# max high 0.094 [m] max distance 0.48 [m] energy  0.0001 J
# new model
# start simulation
# max high 0.17 [m] max distance 0.002 [m] energy  0.0372 J
# new model
# start simulation
# max high 0.154 [m] max distance 0.002 [m] energy  0.0087 J
# new model
# start simulation
# max high 0.095 [m] max distance 0.001 [m] energy  0.0016 J
# new model
# start simulation
# max high 0.089 [m] max distance 0.012 [m] energy  0.0015 J
# new model
# start simulation
# max high 0.096 [m] max distance 0.003 [m] energy  0.0006 J
# new model
# start simulation
# max high 0.169 [m] max distance 0.001 [m] energy  0.0532 J
# new model
# start simulation
# max high 0.089 [m] max distance 0.064 [m] energy  0.0223 J
# new model
# start simulation
# max high 0.14 [m] max distance 0.001 [m] energy  0.0102 J
# new model
# start simulation
# max high 0.092 [m] max distance 0.006 [m] energy  0.0019 J
# new model
# start simulation
# max high 0.11 [m] max distance 0.001 [m] energy  0.0093 J
# new model
# start simulation
# max high 0.086 [m] max distance 0.004 [m] energy  0.0007 J
# new model
# start simulation
# max high 0.152 [m] max distance 0.0 [m] energy  0.0041 J
# new model
# start simulation
# max high 0.112 [m] max distance 0.002 [m] energy  0.0026 J
# new model
# start simulation
# max high 0.154 [m] max distance 0.017 [m] energy  0.0099 J
# new model
# start simulation
# max high 0.15 [m] max distance 0.001 [m] energy  0.024 J
# new model
# start simulation
# max high 0.147 [m] max distance 0.004 [m] energy  0.0322 J
# new model
# start simulation
# max high 0.138 [m] max distance 0.002 [m] energy  0.0167 J
# new model
# start simulation
# max high 0.088 [m] max distance 0.107 [m] energy  0.0001 J
# new model
# start simulation
# max high 0.119 [m] max distance 0.087 [m] energy  0.0073 J
# new model
# start simulation
# max high 0.171 [m] max distance 0.007 [m] energy  0.0457 J
# new model
# start simulation
# max high 0.088 [m] max distance 0.001 [m] energy  0.0012 J
# new model
# start simulation
# max high 0.162 [m] max distance 0.001 [m] energy  0.0046 J
# new model
# start simulation
# max high 0.127 [m] max distance 0.001 [m] energy  0.0231 J
# new model
# start simulation
# max high 0.114 [m] max distance 0.015 [m] energy  0.0143 J
# new model
# start simulation
# max high 0.09 [m] max distance 0.033 [m] energy  0.0001 J
# new model
# start simulation
# max high 0.123 [m] max distance 0.111 [m] energy  0.0037 J
# new model
# start simulation
# max high 0.138 [m] max distance 0.001 [m] energy  0.0145 J
# new model
# start simulation
# max high 0.135 [m] max distance 0.025 [m] energy  0.0 J
# new model
# start simulation
# max high 0.125 [m] max distance 0.081 [m] energy  0.0031 J
# new model
# start simulation
# max high 0.089 [m] max distance 0.013 [m] energy  0.0024 J
# new model
# start simulation
# max high 0.1 [m] max distance 0.011 [m] energy  0.0013 J
# new model
# start simulation
# max high 0.158 [m] max distance 0.005 [m] energy  0.022 J
# new model
# start simulation
# max high 0.096 [m] max distance 0.0 [m] energy  0.0001 J
# new model
# start simulation
# max high 0.097 [m] max distance 0.013 [m] energy  0.0004 J
# new model
# start simulation
# max high 0.128 [m] max distance 0.011 [m] energy  0.0282 J
# new model
# start simulation
# max high 0.144 [m] max distance 0.003 [m] energy  0.0015 J
# new model
# start simulation
# max high 0.086 [m] max distance 0.013 [m] energy  0.0006 J
# new model
# start simulation
# max high 0.093 [m] max distance 0.043 [m] energy  0.0057 J
# new model
# start simulation
# max high 0.139 [m] max distance 0.122 [m] energy  0.0026 J
# new model
# start simulation
# max high 0.157 [m] max distance 0.002 [m] energy  0.0038 J
# new model
# start simulation
# max high 0.145 [m] max distance 0.003 [m] energy  0.0013 J
# new model
# start simulation
# max high 0.136 [m] max distance 0.002 [m] energy  0.0015 J
# new model
# start simulation
# max high 0.127 [m] max distance 0.001 [m] energy  0.0053 J
# new model
# start simulation
# max high 0.119 [m] max distance 0.001 [m] energy  0.0041 J
# new model
# start simulation
# max high 0.151 [m] max distance 0.004 [m] energy  0.0009 J
# new model
# start simulation
# max high 0.146 [m] max distance 0.014 [m] energy  0.0085 J
# new model
# start simulation
# max high 0.162 [m] max distance 0.001 [m] energy  0.0194 J
# new model
# start simulation
# max high 0.099 [m] max distance 0.0 [m] energy  0.0168 J
# new model
# start simulation
# max high 0.137 [m] max distance 0.003 [m] energy  0.0141 J
# new model
# start simulation
# max high 0.092 [m] max distance 0.009 [m] energy  0.0 J
# new model
# start simulation
# max high 0.117 [m] max distance 0.005 [m] energy  0.0176 J
# new model
# start simulation
# max high 0.152 [m] max distance 0.031 [m] energy  0.0021 J
# new model
# start simulation
# max high 0.141 [m] max distance 0.17 [m] energy  0.0 J
# new model
# start simulation
# max high 0.169 [m] max distance 0.124 [m] energy  0.0123 J
# new model
# start simulation
# max high 0.129 [m] max distance 0.001 [m] energy  0.0052 J
# new model
# start simulation
# max high 0.126 [m] max distance 0.011 [m] energy  0.0001 J
# new model
# start simulation
# max high 0.157 [m] max distance 0.059 [m] energy  0.0007 J
# new model
# start simulation
# max high 0.095 [m] max distance 0.001 [m] energy  0.0144 J
# new model
# start simulation
# max high 0.125 [m] max distance 0.005 [m] energy  0.0078 J
# new model
# start simulation
# max high 0.093 [m] max distance 0.01 [m] energy  0.0016 J
# new model
# start simulation
# max high 0.106 [m] max distance 0.007 [m] energy  0.0144 J
# new model
# start simulation
# max high 0.169 [m] max distance 0.003 [m] energy  0.0025 J
# new model
# start simulation
# max high 0.17 [m] max distance 0.003 [m] energy  0.0028 J
# new model
# start simulation
# max high 0.131 [m] max distance 0.041 [m] energy  0.0162 J
# new model
# start simulation
# max high 0.149 [m] max distance 0.164 [m] energy  0.0019 J
# new model
# start simulation
# max high 0.101 [m] max distance 0.019 [m] energy  0.0 J
# new model
# start simulation
# max high 0.103 [m] max distance 0.032 [m] energy  0.0 J
# new model
# start simulation
# max high 0.153 [m] max distance 0.171 [m] energy  0.0471 J
# new model
# start simulation
# max high 0.138 [m] max distance 0.002 [m] energy  0.0152 J
# new model
# start simulation
# max high 0.157 [m] max distance 0.007 [m] energy  0.0049 J
# new model
# start simulation
# max high 0.093 [m] max distance 0.022 [m] energy  0.0028 J
# new model
# start simulation
# max high 0.085 [m] max distance 0.0 [m] energy  0.0001 J
# new model
# start simulation
# max high 0.12 [m] max distance 0.006 [m] energy  0.0155 J
# new model
# start simulation
# max high 0.102 [m] max distance 0.02 [m] energy  0.0004 J
# new model
# start simulation
# max high 0.082 [m] max distance 0.002 [m] energy  0.0105 J
# new model
# start simulation
# max high 0.155 [m] max distance 0.001 [m] energy  0.0056 J
# new model
# start simulation
# max high 0.129 [m] max distance 0.001 [m] energy  0.016 J
# new model
# start simulation
# max high 0.079 [m] max distance 0.0 [m] energy  0.0026 J
# new model
# start simulation
# max high 0.172 [m] max distance 0.006 [m] energy  0.0123 J
# new model
# start simulation
# max high 0.104 [m] max distance 0.004 [m] energy  0.0043 J
# new model
# start simulation
# max high 0.125 [m] max distance 0.005 [m] energy  0.004 J
# new model
# start simulation
# max high 0.148 [m] max distance 0.001 [m] energy  0.0026 J
# new model
# start simulation
# max high 0.14 [m] max distance 0.007 [m] energy  0.0012 J
# new model
# start simulation
# max high 0.166 [m] max distance 0.008 [m] energy  0.0016 J
# new model
# start simulation
# max high 0.099 [m] max distance 0.001 [m] energy  0.0066 J
# new model
# start simulation
# max high 0.082 [m] max distance 0.009 [m] energy  0.0017 J
# new model
# start simulation
# max high 0.077 [m] max distance 0.034 [m] energy  0.0 J
# new model
# start simulation
# max high 0.138 [m] max distance 0.001 [m] energy  0.0061 J
# new model
# start simulation
# max high 0.16 [m] max distance 0.001 [m] energy  0.0303 J
# new model
# start simulation
# max high 0.101 [m] max distance 0.044 [m] energy  0.0086 J
# new model
# start simulation
# max high 0.135 [m] max distance 0.003 [m] energy  0.0012 J
# new model
# start simulation
# max high 0.115 [m] max distance 0.125 [m] energy  0.0005 J
# new model
# start simulation
# max high 0.078 [m] max distance 0.019 [m] energy  0.0014 J
# new model
# start simulation
# max high 0.1 [m] max distance 0.026 [m] energy  0.0001 J
# new model
# start simulation
# max high 0.148 [m] max distance 0.002 [m] energy  0.0166 J
# new model
# start simulation
# max high 0.148 [m] max distance 0.002 [m] energy  0.0165 J
# new model
# start simulation
# max high 0.109 [m] max distance 0.001 [m] energy  0.0008 J
# new model
# start simulation
# max high 0.111 [m] max distance 0.001 [m] energy  0.0148 J
# new model
# start simulation
# max high 0.157 [m] max distance 0.003 [m] energy  0.0302 J
# new model
# start simulation
# max high 0.107 [m] max distance 0.001 [m] energy  0.015 J
# new model
# start simulation
# max high 0.154 [m] max distance 0.002 [m] energy  0.0085 J
# new model
# start simulation
# max high 0.093 [m] max distance 0.001 [m] energy  0.0155 J
# new model
# start simulation
# max high 0.125 [m] max distance 0.006 [m] energy  0.0014 J
# new model
# start simulation
# max high 0.123 [m] max distance 0.038 [m] energy  0.0003 J
# new model
# start simulation
# max high 0.172 [m] max distance 0.012 [m] energy  0.0036 J
# new model
# start simulation
# max high 0.094 [m] max distance 0.001 [m] energy  0.0091 J
# new model
# start simulation
# max high 0.099 [m] max distance 0.007 [m] energy  0.008 J
# new model
# start simulation
# max high 0.171 [m] max distance 0.019 [m] energy  0.0039 J
# new model
# start simulation
# max high 0.09 [m] max distance 0.128 [m] energy  0.0001 J
# new model
# start simulation
# max high 0.133 [m] max distance 0.015 [m] energy  0.0059 J
# new model
# start simulation
# max high 0.151 [m] max distance 0.003 [m] energy  0.0014 J
# new model
# start simulation
# max high 0.101 [m] max distance 0.011 [m] energy  0.0 J
# new model
# start simulation
# max high 0.128 [m] max distance 0.005 [m] energy  0.0075 J
# new model
# start simulation
# max high 0.115 [m] max distance 0.006 [m] energy  0.0033 J
# new model
# start simulation
# max high 0.08 [m] max distance 0.01 [m] energy  0.0006 J
# new model
# start simulation
# max high 0.181 [m] max distance 0.007 [m] energy  0.0003 J
# new model
# start simulation
# max high 0.109 [m] max distance 0.112 [m] energy  0.0001 J
# new model
# start simulation
# max high 0.077 [m] max distance 0.018 [m] energy  0.0 J
# new model
# start simulation
# max high 0.126 [m] max distance 0.043 [m] energy  0.0039 J
# new model
# start simulation
# max high 0.169 [m] max distance 0.01 [m] energy  0.0006 J
# new model
# start simulation
# max high 0.167 [m] max distance 0.004 [m] energy  0.0018 J
# new model
# start simulation
# max high 0.075 [m] max distance 0.002 [m] energy  0.0082 J
# new model
# start simulation
# max high 0.096 [m] max distance 0.001 [m] energy  0.0095 J
# new model
# start simulation
# max high 0.123 [m] max distance 0.004 [m] energy  0.0152 J
# new model
# start simulation
# max high 0.115 [m] max distance 0.002 [m] energy  0.0117 J
# new model
# start simulation
# max high 0.133 [m] max distance 0.056 [m] energy  0.0007 J
# new model
# start simulation
# max high 0.161 [m] max distance 0.0 [m] energy  0.0103 J
# new model
# start simulation
# max high 0.149 [m] max distance 0.004 [m] energy  0.0057 J
# new model
# start simulation
# max high 0.151 [m] max distance 0.163 [m] energy  0.0032 J
# new model
# start simulation
# max high 0.118 [m] max distance 0.001 [m] energy  0.0024 J
# new model
# start simulation
# max high 0.177 [m] max distance 0.0 [m] energy  0.0015 J
# new model
# start simulation
# max high 0.109 [m] max distance 0.0 [m] energy  0.0174 J
# new model
# start simulation
# max high 0.146 [m] max distance 0.006 [m] energy  0.0325 J
# new model
# start simulation
# max high 0.143 [m] max distance 0.011 [m] energy  0.0006 J
# new model
# start simulation
# max high 0.161 [m] max distance 0.009 [m] energy  0.0 J
# new model
# start simulation
# max high 0.149 [m] max distance 0.004 [m] energy  0.0011 J
# new model
# start simulation
# max high 0.134 [m] max distance 0.019 [m] energy  0.0051 J
# new model
# start simulation
# max high 0.132 [m] max distance 0.024 [m] energy  0.0002 J
# new model
# start simulation
# max high 0.168 [m] max distance 0.0 [m] energy  0.0174 J
# new model
# start simulation
# max high 0.166 [m] max distance 0.008 [m] energy  0.0015 J
# new model
# start simulation
# max high 0.137 [m] max distance 0.0 [m] energy  0.0091 J
# new model
# start simulation
# max high 0.1 [m] max distance 0.017 [m] energy  0.0 J
# new model
# start simulation
# max high 0.149 [m] max distance 0.006 [m] energy  0.0009 J
# new model
# start simulation
# max high 0.107 [m] max distance 0.022 [m] energy  0.0 J
# new model
# start simulation
# max high 0.082 [m] max distance 0.033 [m] energy  0.0003 J
# new model
# start simulation
# max high 0.099 [m] max distance 0.018 [m] energy  0.0001 J
# new model
# start simulation
# max high 0.14 [m] max distance 0.01 [m] energy  0.0158 J
# new model
# start simulation
# max high 0.098 [m] max distance 0.017 [m] energy  0.0016 J
# new model
# start simulation
# max high 0.129 [m] max distance 0.012 [m] energy  0.0108 J
# new model
# start simulation
# max high 0.16 [m] max distance 0.005 [m] energy  0.0169 J
# new model
# start simulation
# max high 0.108 [m] max distance 0.0 [m] energy  0.0157 J
# new model
# start simulation
# max high 0.104 [m] max distance 0.001 [m] energy  0.0144 J
# new model
# start simulation
# max high 0.157 [m] max distance 0.001 [m] energy  0.0245 J
# new model
# start simulation
# max high 0.147 [m] max distance 0.009 [m] energy  0.021 J
# new model
# start simulation
# max high 0.094 [m] max distance 0.007 [m] energy  0.0148 J
# new model
# start simulation
# max high 0.142 [m] max distance 0.002 [m] energy  0.014 J
# new model
# start simulation
# max high 0.098 [m] max distance 0.001 [m] energy  0.0059 J
# new model
# start simulation
# max high 0.108 [m] max distance 0.001 [m] energy  0.0156 J
# new model
# start simulation
# max high 0.141 [m] max distance 0.04 [m] energy  0.0003 J
# new model
# start simulation
# max high 0.104 [m] max distance 0.006 [m] energy  0.0004 J
# new model
# start simulation
# max high 0.129 [m] max distance 0.004 [m] energy  0.0127 J
# new model
# start simulation
# max high 0.08 [m] max distance 0.005 [m] energy  0.0002 J
# new model
# start simulation
# max high 0.074 [m] max distance 0.004 [m] energy  0.0006 J
# new model
# start simulation
# max high 0.107 [m] max distance 0.023 [m] energy  0.0004 J
# new model
# start simulation
# max high 0.114 [m] max distance 0.009 [m] energy  0.0003 J
# new model
# start simulation
# max high 0.165 [m] max distance 0.001 [m] energy  0.0305 J
# new model
# start simulation
# max high 0.137 [m] max distance 0.053 [m] energy  0.0286 J
# new model
# start simulation
# max high 0.168 [m] max distance 0.0 [m] energy  0.0013 J
# new model
# start simulation
# max high 0.093 [m] max distance 0.017 [m] energy  0.001 J
# new model
# start simulation
# max high 0.164 [m] max distance 0.151 [m] energy  0.0041 J
# new model
# start simulation
# max high 0.155 [m] max distance 0.001 [m] energy  0.0072 J
# new model
# start simulation
# max high 0.131 [m] max distance 0.143 [m] energy  0.0032 J
# new model
# start simulation
# max high 0.116 [m] max distance 0.067 [m] energy  0.0 J
# new model
# start simulation
# max high 0.165 [m] max distance 0.002 [m] energy  0.0191 J
# new model
# start simulation
# max high 0.108 [m] max distance 0.0 [m] energy  0.0022 J
# new model
# start simulation
# max high 0.145 [m] max distance 0.003 [m] energy  0.0208 J
# new model
# start simulation
# max high 0.153 [m] max distance 0.076 [m] energy  0.0007 J
# new model
# start simulation
# max high 0.165 [m] max distance 0.004 [m] energy  0.0078 J
# new model
# start simulation
# max high 0.132 [m] max distance 0.014 [m] energy  0.0003 J
# new model
# start simulation
# max high 0.122 [m] max distance 0.006 [m] energy  0.012 J
# new model
# start simulation
# max high 0.142 [m] max distance 0.007 [m] energy  0.0022 J
# new model
# start simulation
# max high 0.098 [m] max distance 0.011 [m] energy  0.0003 J
# new model
# start simulation
# max high 0.161 [m] max distance 0.001 [m] energy  0.0004 J
# new model
# start simulation
# max high 0.107 [m] max distance 0.017 [m] energy  0.0001 J
# new model
# start simulation
# max high 0.115 [m] max distance 0.005 [m] energy  0.0009 J
# new model
# start simulation
# max high 0.163 [m] max distance 0.002 [m] energy  0.0109 J
# new model
# start simulation
# max high 0.171 [m] max distance 0.014 [m] energy  0.0084 J
# new model
# start simulation
# max high 0.167 [m] max distance 0.006 [m] energy  0.002 J
# new model
# start simulation
# max high 0.076 [m] max distance 0.005 [m] energy  0.0006 J
# new model
# start simulation
# max high 0.155 [m] max distance 0.007 [m] energy  0.0116 J
# new model
# start simulation
# max high 0.122 [m] max distance 0.008 [m] energy  0.0004 J
# new model
# start simulation
# max high 0.091 [m] max distance 0.039 [m] energy  0.0017 J
# new model
# start simulation
# max high 0.075 [m] max distance 0.014 [m] energy  0.0 J
# new model
# start simulation
# max high 0.103 [m] max distance 0.021 [m] energy  0.0 J
# new model
# start simulation
# max high 0.107 [m] max distance 0.16 [m] energy  0.0188 J
# new model
# start simulation
# max high 0.147 [m] max distance 0.003 [m] energy  0.007 J
# new model
# start simulation
# max high 0.078 [m] max distance 0.004 [m] energy  0.0017 J
# new model
# start simulation
# max high 0.155 [m] max distance 0.037 [m] energy  0.0019 J
# new model
# start simulation
# max high 0.145 [m] max distance 0.003 [m] energy  0.006 J
# new model
# start simulation
# max high 0.164 [m] max distance 0.004 [m] energy  0.0088 J
# new model
# start simulation
# max high 0.15 [m] max distance 0.017 [m] energy  0.0056 J
# new model
# start simulation
# max high 0.15 [m] max distance 0.108 [m] energy  0.0024 J
# new model
# start simulation
# max high 0.13 [m] max distance 0.001 [m] energy  0.009 J
# new model
# start simulation
# max high 0.08 [m] max distance 0.008 [m] energy  0.0006 J
# new model
# start simulation
# max high 0.165 [m] max distance 0.0 [m] energy  0.0128 J
# new model
# start simulation
# max high 0.08 [m] max distance 0.0 [m] energy  0.0005 J
# new model
# start simulation
# max high 0.147 [m] max distance 0.006 [m] energy  0.0387 J
#             l1          l2          l5 compression rest_angle  stiffness  \
# 0    51.848248  154.233896  117.376007   24.321596  47.112026   8.370281
# 1    44.860948  120.563504  128.922676   14.196282  12.572459   6.326965
# 2    59.228524   89.970233  152.992123     5.18714  40.355264   5.884088
# 3    44.332867  158.148942  156.321868   33.837403  14.126629  10.402703
# 4    52.730282    164.8459   55.182443   20.605115   15.21545   4.359833
# ..         ...         ...         ...         ...        ...        ...
# 295  47.338288  130.039397   52.345029     7.56905  52.056259    12.5264
# 296   41.65606    77.82922   89.567688    12.57841  48.317037   5.343452
# 297  30.935907   162.94218  110.492994   39.384544  14.935351   9.085767
# 298  38.336386   72.710334  110.588113    34.97298   19.41356   13.49913
# 299   37.56824   144.58518  160.044457   21.228673  42.155958   6.910243
#
#     link_angle
# 0    47.473843
# 1    26.213073
# 2    32.373727
# 3     36.62152
# 4    48.879617
# ..         ...
# 295   10.30875
# 296  15.388205
# 297  34.529042
# 298  11.836814
# 299  64.592932
#
# [300 rows x 7 columns]
#             0
# 0    0.000046
# 1    0.000002
# 2    0.000013
# 3    0.000067
# 4    0.000018
# ..        ...
# 295  0.000005
# 296  0.000084
# 297  0.000000
# 298  0.000000
# 299  0.000040
#
# [300 rows x 1 columns]
# apply PCA

# %%
Algorithm.biplot(principal_components,result, pca, labels=labels, label_size=8, arrow_length=5, arrow_width=0.01)

# %%
Algorithm.pca_plot(principal_components,result)
