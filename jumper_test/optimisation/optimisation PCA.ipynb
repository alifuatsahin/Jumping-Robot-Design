# %% [markdown]
# # Data-Driven Optimisation - PCA
#
# In this notebook, we will run data driven algorithm to optimise the parameter of our problem

# %%
import Model #import the simulation and the model
import Algorithm #import data-driven algorithms 
import numpy as np
import matplotlib.pyplot as plt
# Out:
# pybullet build time: Mar  5 2024 15:57:27

# %% [markdown]
# ## PCA

# %%
principal_components,result,pca,labels,df = Algorithm.pca(25,4)
# Out:
# Create pool
# new model
# start simulation
# max high 0.12 [m] max distance 0.04 [m] energy  1814.99 J
# new model
# start simulation
# max high 0.04 [m] max distance 0.0 [m] energy  560.61 J
# new model
# start simulation
# max high 1.15 [m] max distance 0.83 [m] energy  3169.34 J
# new model
# start simulation
# max high 0.33 [m] max distance 0.38 [m] energy  372.6 J
# new model
# start simulation
# max high 0.53 [m] max distance 2.08 [m] energy  1950.36 J
# new model
# start simulation
# max high 1.04 [m] max distance 3.22 [m] energy  2516.13 J
# new model
# start simulation
# max high 0.11 [m] max distance 0.3 [m] energy  1121.71 J
# new model
# start simulation
# max high 0.21 [m] max distance 0.16 [m] energy  454.12 J
# new model
# start simulation
# max high 19.06 [m] max distance 6.41 [m] energy  159.94 J
# new model
# start simulation
# max high 0.13 [m] max distance 0.01 [m] energy  544.92 J
# new model
# start simulation
# max high 0.87 [m] max distance 1.04 [m] energy  2770.16 J
# new model
# start simulation
# max high 0.11 [m] max distance 0.08 [m] energy  3502.32 J
# new model
# start simulation
# max high 17.98 [m] max distance 1.1 [m] energy  1010.09 J
# new model
# start simulation
# max high 0.15 [m] max distance 0.02 [m] energy  2530.64 J
# new model
# start simulation
# max high 26.97 [m] max distance 10.91 [m] energy  110.39 J
# new model
# start simulation
# max high 0.09 [m] max distance 0.02 [m] energy  62.56 J
# new model
# start simulation
# max high 0.25 [m] max distance 0.15 [m] energy  1464.05 J
# new model
# start simulation
# max high 0.12 [m] max distance 0.18 [m] energy  573.2 J
# new model
# start simulation
# max high 0.12 [m] max distance 0.05 [m] energy  895.22 J
# new model
# start simulation
# max high 0.83 [m] max distance 4.84 [m] energy  908.52 J
# new model
# start simulation
# max high 1.17 [m] max distance 0.4 [m] energy  1663.93 J
# new model
# start simulation
# max high 0.12 [m] max distance 0.01 [m] energy  82.18 J
# new model
# start simulation
# max high 0.32 [m] max distance 0.15 [m] energy  877.6 J
# new model
# start simulation
# max high 0.06 [m] max distance 31.78 [m] energy  423.89 J
# new model
# start simulation
# max high 0.53 [m] max distance 1.68 [m] energy  83.27 J
#          Link1       Link2       Link3       Link4       Link5 Compression  \
# 0   108.707306   89.987831   81.468341  141.142144   87.742285   20.301631
# 1   140.129608   36.111725   91.954028   87.439573   28.082945   15.774892
# 2   131.613354   36.274058  140.756361   36.906372   88.061278   22.135564
# 3    31.960475  102.826945  121.679435    66.44386   96.667286   13.274133
